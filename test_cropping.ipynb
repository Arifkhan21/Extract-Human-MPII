# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# %%
image = Image.open('000071686.jpg')
# plt.imshow(image)
im = cv2.imread('000071686.jpg')
plt.imshow(im)

# %%
img =cv2.resize(im,(224,224))
plt.imshow(img)
img.shape
cv2.imwrite('hell.jpg',img)
# Out:
# True

# %%
imag = cv2.resize(img,(512,224))
plt.imshow(imag)
imag.shape
cv2.imwrite('hello.jpg',imag)
# Out:
# True
